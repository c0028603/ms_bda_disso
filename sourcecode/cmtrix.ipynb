# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
a = np.array([[1262475,270267],[6,2]])
a
# Out:
# array([[1262475,  270267],
#        [      6,       2]])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

ax = sns.heatmap(a, annot=True, cmap='flare')

ax.set_title('ANN-MLP-keras - 13 percent of data with full augmentation \n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
a = np.array([[1685592,1233],[8,0]])
ax = sns.heatmap(a, annot=True, cmap='flare')

ax.set_title('Decision Tree confusion matrix \n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['istumor-0','istumor - 1'])
ax.yaxis.set_ticklabels(['istumor-0','istumor - 1'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
a = np.array([[1656616,30209],[5,3]])
ax = sns.heatmap(a, annot=True, cmap='flare')

ax.set_title('ANN-MLP-keras - full data with 25 percent augmentation \n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['istumor-0','istumor - 1'])
ax.yaxis.set_ticklabels(['istumor-0','istumor - 1'])

## Display the visualization of the Confusion Matrix.
plt.show()
